# %% [markdown]
# #Steps
# #1 import the ConversationSummaryBufferMemory, ConversationChain, ChatBedrock (BedrockChat) Langchain Modules
# from langchain.chains import ConversationChain
# from langchain.memory import ConversationSummaryBufferMemory
# from langchain_aws import ChatBedrock
#
# #2a Write a function for invoking model- client connection with Bedrock with profile, model_id & Inference params- model_kwargs
# def demo_chatbot():
#     demo_llm=ChatBedrock(
#        credentials_profile_name='default',
#        model_id='anthropic.claude-3-haiku-20240307-v1:0',
#        model_kwargs= {
#            "max_tokens": 300,  #Limits the response length
#            "temperature": 0.1,  #Makes responses more focused/deterministic
#            "top_p": 0.9,
#            "stop_sequences": ["\n\nHuman:"]} )
#     return demo_llm
#
# #2b Test out the LLM with Predict method instead use invoke method
#     #return demo_llm.invoke(input_text)
# #response=demo_chatbot(input_text="Hi, what is the temperature in new york in January?")
# #print(response)
#
# #3 Create a Function for  ConversationSummaryBufferMemory  (llm and max token limit)
# def demo_memory():
#     llm_data=demo_chatbot()
#     memory=ConversationSummaryBufferMemory(llm=llm_data,max_token_limit=300)
#     return memory
#
# #4 Create a Function for Conversation Chain - Input text + Memory
# def demo_conversation(input_text,memory):
#     llm_chain_data=demo_chatbot()
#     llm_conversation=ConversationChain(llm=llm_chain_data,memory=memory,verbose=True)
#
# #5 Chat response using invoke (Prompt template)
#     chat_reply=llm_conversation.invoke(input_text)
#     return chat_reply['response']
#
# #1 https://python.langchain.com/v0.1/docs/integrations/llms/bedrock/
# #pip install -U langchain-aws
# #pip install anthropic

# %%
# !pip install langchain
# !pip install langchain-aws
# !pip install anthropic
# Out:
# Requirement already satisfied: langchain in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (0.3.14)
# Requirement already satisfied: PyYAML>=5.3 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (3.11.11)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.29 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (0.3.29)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.3 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (0.3.5)
# Requirement already satisfied: langsmith<0.3,>=0.1.17 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (0.2.10)
# Requirement already satisfied: numpy<3,>=1.26.2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (2.2.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (2.10.5)
# Requirement already satisfied: requests<3,>=2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.29->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain) (3.10.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from requests<3,>=2->langchain) (2024.12.14)
# Requirement already satisfied: anyio in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.29->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: langchain-aws in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (0.2.10)
# Requirement already satisfied: boto3>=1.35.74 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-aws) (1.35.97)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.27 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-aws) (0.3.29)
# Requirement already satisfied: numpy<3,>=1.26.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-aws) (2.2.1)
# Requirement already satisfied: pydantic<3,>=2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-aws) (2.10.5)
# Requirement already satisfied: botocore<1.36.0,>=1.35.97 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from boto3>=1.35.74->langchain-aws) (1.35.97)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from boto3>=1.35.74->langchain-aws) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from boto3>=1.35.74->langchain-aws) (0.10.4)
# Requirement already satisfied: PyYAML>=5.3 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-aws) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-aws) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-aws) (0.2.10)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-aws) (24.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-aws) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langchain-core<0.4.0,>=0.3.27->langchain-aws) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from pydantic<3,>=2->langchain-aws) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from pydantic<3,>=2->langchain-aws) (2.27.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from botocore<1.36.0,>=1.35.97->boto3>=1.35.74->langchain-aws) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from botocore<1.36.0,>=1.35.97->boto3>=1.35.74->langchain-aws) (2.3.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.27->langchain-aws) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (3.10.14)
# Requirement already satisfied: requests<3,>=2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (1.0.0)
# Requirement already satisfied: anyio in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (4.8.0)
# Requirement already satisfied: certifi in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (1.0.7)
# Requirement already satisfied: idna in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (0.14.0)
# Requirement already satisfied: six>=1.5 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.97->boto3>=1.35.74->langchain-aws) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from requests<3,>=2->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (3.4.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.3,>=0.1.125->langchain-core<0.4.0,>=0.3.27->langchain-aws) (1.3.1)
# Requirement already satisfied: anthropic in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (0.42.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anthropic) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anthropic) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anthropic) (2.10.5)
# Requirement already satisfied: sniffio in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anthropic) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpx<1,>=0.23.0->anthropic) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpx<1,>=0.23.0->anthropic) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->anthropic) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /Users/satishgundu/Desktop/2025/.venv1/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.27.2)

# %%
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain_aws import ChatBedrock

# %%
#1 import the required modules
from langchain_core.runnables import RunnableWithMessageHistory
from langchain_core.messages import HumanMessage, AIMessage
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_aws import ChatBedrock

# %%
def demo_chatbot():
    demo_llm=ChatBedrock(
       credentials_profile_name='default',
       model_id='anthropic.claude-3-haiku-20240307-v1:0',
       model_kwargs= {
           "max_tokens": 300,
           "temperature": 0.1,
           "top_p": 0.9,
           "stop_sequences": ["\n\nHuman:"]} )
    return demo_llm

# %%
def demo_memory():
    chat_history = BaseChatMessageHistory()
    return chat_history

# %%
def demo_conversation(input_text, memory):
    llm_chain_data = demo_chatbot()
    
    # Create a runnable with message history
    runnable = RunnableWithMessageHistory(
        llm_chain_data,
        memory,
        input_messages_key="input",
        history_messages_key="chat_history"
    )
    
    # Invoke the conversation
    response = runnable.invoke(
        {"input": input_text},
        config={"configurable": {"session_id": "chat_session"}}
    )
    
    return response
